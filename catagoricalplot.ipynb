# %% [markdown]
# ## Categorical Data Plots
#  Now let's discuss using seaborn to plot categorical data! There are a few main plot types for this:
#
# * boxplot
# * violinplot
# * stripplot
# * swarmplot
# * barplot
# * countplot
# * Let's go through examples of each!

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df=sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.countplot(x=df["sex"],hue=df["smoker"]) #this func helps to count and make plot of any column
              #bydefault it will be on y axis so to make it on x axis do x=
# HUE helps to hightlight user requirement
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.barplot(x=df["sex"],y=df["total_bill"],estimator=np.sum) #this func helps to do barplot
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>
